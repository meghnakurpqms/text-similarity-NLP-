# %%
# %store -r dev_set

# %%
# %store -r train_set

# %%
dev_set
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                       2         3
# 0                                             Sentence2  Gold Tag
# ...

# %%
train_set
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2         3
# 0                                             Sentence2  Gold Tag
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
dev_set[4] = dev_set[1].apply(word_tokenize) 
dev_set[5] = dev_set[2].apply(word_tokenize)

# %%
train_set[4] = train_set[1].apply(word_tokenize) 
train_set[5] = train_set[2].apply(word_tokenize)

# %%
train_set
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2         3  \
# 0                                             Sentence2  Gold Tag
# ...

# %%
cols = list(dev_set)
cols.insert(3, cols.pop(4))
cols.insert(4,cols.pop(5))

# %%
cols = list(train_set)
cols.insert(3, cols.pop(4))
cols.insert(4,cols.pop(5))

# %%
dev_set2 = dev_set.ix[:, cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexing.py:822: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   retval = getattr(retval, self.name)._getitem_axis(key, axis=i)

# %%
train_set2 = train_set.ix[:, cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
train_set2
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
train_set2
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
import nltk
lemmatizer = nltk.stem.WordNetLemmatizer()

# %%
def lemmatize_text(text):
    return [lemmatizer.lemmatize(w) for w in text]

# %%
dev_set2[6] = dev_set2[4].apply(lemmatize_text)
dev_set2[7] = dev_set2[5].apply(lemmatize_text)

# %%
train_set2[6] = train_set2[4].apply(lemmatize_text)
train_set2[7] = train_set2[5].apply(lemmatize_text)

# %%
dev_set2
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                       2  \
# 0                                             Sentence2
# 1     The leaders benefit aujourd' hui of a new luck...
# ...

# %%
train_set2
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
cols = list(dev_set2)
cols.insert(5,cols.pop(6))
cols.insert(6,cols.pop(7))
dev_set3 = dev_set2.ix[:,cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.

# %%
cols = list(train_set2)
cols.insert(5,cols.pop(6))
cols.insert(6,cols.pop(7))
train_set3 = train_set2.ix[:,cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.

# %%
dev_set3
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                       2  \
# 0                                             Sentence2
# 1     The leaders benefit aujourd' hui of a new luck...
# ...

# %%
train_set3
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
from nltk import pos_tag

# %%
dev_set3[8] = dev_set3[6].apply(pos_tag) 
dev_set3[9] = dev_set3[7].apply(pos_tag)

# %%
train_set3[8] = train_set3[6].apply(pos_tag) 
train_set3[9] = train_set3[7].apply(pos_tag)

# %%
dev_set3
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                       2  \
# 0                                             Sentence2
# 1     The leaders benefit aujourd' hui of a new luck...
# ...

# %%
train_set3
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
cols = list(dev_set3)
cols.insert(7,cols.pop(8))
cols.insert(8,cols.pop(9))
dev_set4 = dev_set3.ix[:,cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.

# %%
cols = list(train_set3)
cols.insert(7,cols.pop(8))
cols.insert(8,cols.pop(9))
train_set4 = train_set3.ix[:,cols]
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   after removing the cwd from sys.path.

# %%
train_set4
# Out:
#            0                                                  1  \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                       2  \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
import spacy

# %%
nlp = spacy.load("en")

# %%
def dependency_parsing_tree(text):
    res = []
    sent = nlp(text)
    for token in sent:
        res.extend([token.text, token.tag_, token.head.text, token.dep_])
    return res

# %%
dev_set4[10] = dev_set4[1].apply(dependency_parsing_tree)
dev_set4[11] = dev_set4[2].apply(dependency_parsing_tree)

# %%
train_set4[10] = train_set4[1].apply(dependency_parsing_tree)
train_set4[11] = train_set4[2].apply(dependency_parsing_tree)

# %%
dev_set4
# Out:
#           0                                                  1   \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                      2   \
# 0                                             Sentence2
# 1     The leaders benefit aujourd' hui of a new luck...
# ...

# %%
train_set4
# Out:
#           0                                                  1   \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                      2   \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
import nltk 
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/jyotsnaprasad/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
from nltk.corpus import wordnet as wn

# %%
import collections 
def syn_hyper(text):
    syn = []
    for i in text:
        d = {}
        for ss in wn.synsets(i):
            for hyper in ss.hypernyms():
#             syn.extend([ss, ss.hypernyms()])
                d[i] = [ss,hyper]
        syn.append(d)
    return syn

# %%
dev_set4[12] = dev_set4[6].apply(syn_hyper)
dev_set4[13] = dev_set4[7].apply(syn_hyper)

# %%
train_set4[12] = train_set4[6].apply(syn_hyper)
train_set4[13] = train_set4[7].apply(syn_hyper)

# %%
dev_set4
# Out:
#           0                                                  1   \
# 0         id                                          Sentence1
# 1        s_1  The leaders have now been given a new chance a...
# 2        s_2  Amendment No 7 proposes certain changes in the...
# 3        s_3  Let me remind you that our allies include ferv...
# 4        s_4        The vote will take place today at 5.30 p.m.
# ...      ...                                                ...
# 1156  s_1205  Yucaipa owned Dominick's before selling the ch...
# 1157  s_1206  The unemployment rate rose a tenth of a percen...
# 1158  s_1207  As part of his deal, Mr. Delainey has agreed t...
# 1159  s_1208  Graves reported from Albuquerque, Villafranca ...
# 1160  s_1209  A 25 percent increase would raise undergraduat...
#
#                                                      2   \
# 0                                             Sentence2
# 1     The leaders benefit aujourd' hui of a new luck...
# ...

# %%
train_set4
# Out:
#           0                                                  1   \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                      2   \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
import collections 
def syn_hypo(text):
    syn = []
    for i in text:
        d = {}
        for ss in wn.synsets(i):
            for hypo in ss.hyponyms():
                
#             syn.extend([ss, ss.hypernyms()])
                d[i] = [ss,hypo]
        syn.append(d)
    return syn

# %%
dev_set4[14] = dev_set4[6].apply(syn_hypo)
dev_set4[15] = dev_set4[7].apply(syn_hypo)

# %%
train_set4[14] = train_set4[6].apply(syn_hypo)
train_set4[15] = train_set4[7].apply(syn_hypo)

# %%
train_set4
# Out:
#           0                                                  1   \
# 0         id                                          Sentence1
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                      2   \
# 0                                             Sentence2
# 1     But other sources close to the sale said Viven...
# ...

# %%
import collections 
def syn_mero(text):
    syn = []
    for i in text:
        d = {}
        for ss in wn.synsets(i):
            for mero in ss.part_meronyms():
                
#             syn.extend([ss, ss.hypernyms()])
                d[i] = [ss,mero]
        syn.append(d)
    return syn

# %%
train_set4[16] = train_set4[6].apply(syn_mero)
train_set4[17] = train_set4[7].apply(syn_mero)

# %%
dev_set4[16] = dev_set4[6].apply(syn_mero)
dev_set4[17] = dev_set4[7].apply(syn_mero)

# %%
dev_set5 = dev_set4.iloc[1:,:]

# %%
train_set5 = train_set4.iloc[1:,:]

# %%
import collections 
def syn_hypo(text):
    syn = []
    for i in text:
        if(str(i).isalnum()):
            names = []
            for ss in wn.synsets(i):
                for hypo in ss.hyponyms():
                    names = [hypo.name().split('.',1)[0]]
                    syn.extend(names)
    return syn

# %%
import collections 
def syn_hyper(text):
    syn = []
    for i in text:
        if(str(i).isalnum()):
            names = []
            for ss in wn.synsets(i):
                for hyper in ss.hypernyms():
                    names = [hyper.name().split('.',1)[0]]
                    syn.extend(names)
    return syn

# %%
model_df = train_set5[[0,3]].copy()

# %%
model_df
# Out:
#            0  3
# 1        s_1  4
# 2        s_2  4
# 3        s_3  3
# 4        s_4  3
# 5        s_5  2
# ...      ... ..
# 1453  s_1480  5
# 1454  s_1481  5
# 1455  s_1482  5
# 1456  s_1483  5
# 1457  s_1484  1
#
# [1457 rows x 2 columns]

# %%
model_df[1] = train_set5[6].apply(syn_hypo)
model_df[2] = train_set5[7].apply(syn_hypo)

# %%
model_df[6] = train_set5[6].apply(syn_hyper)
model_df[7] = train_set5[7].apply(syn_hyper)

# %%
model_df
# Out:
#            0  3                                                  1  \
# 1        s_1  4  [birthplace, derivation, fountainhead, headwat...
# 2        s_2  4  [account, affirm, condemn, consecrate, count_o...
# 3        s_3  3  [library_fine, amerce, abound, accept, account...
# 4        s_4  3  [african-american, alabaman, alaskan, anglo-am...
# 5        s_5  2  [hybrid, syndrome, compass_plant, corn_chamomi...
# ...      ... ..                                                ...
# 1453  s_1480  5  [accomplishment, aggression, alienation, appli...
# 1454  s_1481  5  [monad, singleton, velleity, hope, please, con...
# 1455  s_1482  5  [british_parliament, knesset, oireachtas, ackn...
# 1456  s_1483  5  [american_labor_party, american_party, anti-ma...
# 1457  s_1484  1  [bill, bucksaw, crown_saw, folding_saw, hacksa...
#
#                                                       2  \
# 1     [birthplace, derivation, fountainhead, headwat...
# ...

# %%
from nltk.corpus import stopwords

def cosine_similarity_hypo(f):
    X = set(list(f[1]))
    Y = set(list(f[2]))

    sw = stopwords.words('english')
    
    X_set = {w for w in X if not w in sw}  
    Y_set = {w for w in Y if not w in sw}
    
    rvector = X.union(Y)

    l1 = []
    l2 = []

    for w in rvector: 
        if w in X: l1.append(1) # create a vector 
        else: l1.append(0) 
        if w in Y: l2.append(1) 
        else: l2.append(0) 
    c = 0

    # cosine formula  
    for i in range(len(rvector)): 
            c+= l1[i]*l2[i]
    
    if sum(l1)*sum(l2) == 0:
        cosine = 0
    else:
        cosine = c / float((sum(l1)*sum(l2))**0.5) 
    return cosine

# %%
from nltk.corpus import stopwords

def cosine_similarity_hyper(f):
    X = set(list(f[6]))
    Y = set(list(f[7]))
    
    sw = stopwords.words('english')
    
    X_set = {w for w in X if not w in sw}  
    Y_set = {w for w in Y if not w in sw}
    
    
    rvector = X.union(Y)

    l1 = []
    l2 = []

    for w in rvector: 
        if w in X: l1.append(1) # create a vector 
        else: l1.append(0) 
        if w in Y: l2.append(1) 
        else: l2.append(0) 
    c = 0

    # cosine formula  
    for i in range(len(rvector)): 
            c+= l1[i]*l2[i]
    
    if sum(l1)*sum(l2) == 0:
        cosine = 0
    else:
        cosine = c / float((sum(l1)*sum(l2))**0.5) 
    return cosine

# %%
def jaccard_similarity(f):
    
    list1 = list(f[6])
    list2 = list(f[7])
    intersection = len(list(set(list1).intersection(list2)))
    union = (len(list1) + len(list2)) - intersection
    return float(intersection) / union

# %%
model_df[5] = model_df.apply(cosine_similarity_hypo,axis = 1)

# %%
model_df[8] = model_df.apply(cosine_similarity_hyper,axis = 1)

# %%
model_df[10] = model_df.apply(jaccard_similarity,axis = 1)

# %%
model_df
# Out:
#           0  3                                                  1   \
# 1        s_1  4  [birthplace, derivation, fountainhead, headwat...
# 2        s_2  4  [account, affirm, condemn, consecrate, count_o...
# 3        s_3  3  [library_fine, amerce, abound, accept, account...
# 4        s_4  3  [african-american, alabaman, alaskan, anglo-am...
# 5        s_5  2  [hybrid, syndrome, compass_plant, corn_chamomi...
# ...      ... ..                                                ...
# 1453  s_1480  5  [accomplishment, aggression, alienation, appli...
# 1454  s_1481  5  [monad, singleton, velleity, hope, please, con...
# 1455  s_1482  5  [british_parliament, knesset, oireachtas, ackn...
# 1456  s_1483  5  [american_labor_party, american_party, anti-ma...
# 1457  s_1484  1  [bill, bucksaw, crown_saw, folding_saw, hacksa...
#
#                                                      2   \
# 1     [birthplace, derivation, fountainhead, headwat...
# ...

# %%
import numpy as np 
conditions = [
    (model_df[8] >= 0.7) & (model_df[8] < 0.85),
    (model_df[8] >= 0.55) & (model_df[8] < 0.7),
    (model_df[8] >= 0.4) & (model_df[8] < 0.55), 
    (model_df[8] >= 0.1) & (model_df[8] < 0.4), 
    (model_df[8] >= 0.85)]
choices = [int(4),int(3),int(2),int(1),int(5)]
model_df[11] = np.select(conditions, choices, default=0)

# %%
import numpy as np 
conditions = [
    (model_df[5] >= 0.7) & (model_df[5] < 0.85),
    (model_df[5] >= 0.55) & (model_df[5] < 0.7),
    (model_df[5] >= 0.4) & (model_df[5] < 0.55), 
    (model_df[5] >= 0.1) & (model_df[5] < 0.4), 
    (model_df[5] >= 0.85)]
choices = [4,3,2,1,5]

model_df[13] = np.select(conditions, choices, default=0)

# %%
import numpy as np 
conditions = [
    (model_df[10] >= 0.7) & (model_df[10] < 0.85),
    (model_df[10] >= 0.55) & (model_df[10] < 0.7),
    (model_df[10] >= 0.4) & (model_df[10] < 0.55), 
    (model_df[10] >= 0.1) & (model_df[10] < 0.4), 
    (model_df[10] >= 0.85)]
choices = [4,3,2,1,5]

model_df[14] = np.select(conditions, choices, default=0)

# %%
model_df
# Out:
#            0  3                                                  1  \
# 1        s_1  4  [birthplace, derivation, fountainhead, headwat...
# 2        s_2  4  [account, affirm, condemn, consecrate, count_o...
# 3        s_3  3  [library_fine, amerce, abound, accept, account...
# 4        s_4  3  [african-american, alabaman, alaskan, anglo-am...
# 5        s_5  2  [hybrid, syndrome, compass_plant, corn_chamomi...
# ...      ... ..                                                ...
# 1453  s_1480  5  [accomplishment, aggression, alienation, appli...
# 1454  s_1481  5  [monad, singleton, velleity, hope, please, con...
# 1455  s_1482  5  [british_parliament, knesset, oireachtas, ackn...
# 1456  s_1483  5  [american_labor_party, american_party, anti-ma...
# 1457  s_1484  1  [bill, bucksaw, crown_saw, folding_saw, hacksa...
#
#                                                       2  \
# 1     [birthplace, derivation, fountainhead, headwat...
# ...

# %%
def predict_class(f):
    
    x = (f[3])
    y = (f[11])
    

    if x == y:
        return "yes"
    else:
        return "no"

# %%
model_df[10] = model_df.apply(jaccard_similarity,axis = 1)

# %%
predict_df = model_df[[3,11,13,14]].copy()

# %%
predict_df
# Out:
#      3   11  13  14
# 1     4   4   2   2
# 2     4   2   2   1
# 3     3   3   2   2
# 4     3   4   4   2
# 5     2   3   3   1
# ...  ..  ..  ..  ..
# 1453  5   2   3   1
# 1454  5   2   1   1
# 1455  5   5   5   4
# 1456  5   4   3   2
# 1457  1   2   1   1
#
# [1457 rows x 4 columns]

# %%
predict_df.to_csv("cosine_hyper", sep='\t', encoding='utf-8')

# %%
import pandas as pd 
predict_df = predict_df.apply(pd.to_numeric)

# %%
predict_df
# Out:
#        3   11  13  14
# 1     4.0   4   2   2
# 2     4.0   2   2   1
# 3     3.0   3   2   2
# 4     3.0   4   4   2
# 5     2.0   3   3   1
# ...   ...  ..  ..  ..
# 1453  5.0   2   3   1
# 1454  5.0   2   1   1
# 1455  5.0   5   5   4
# 1456  5.0   4   3   2
# 1457  1.0   2   1   1
#
# [1457 rows x 4 columns]

# %%
predict_df['predict_cosine_hyper'] = np.where(predict_df[3] == predict_df[11],'yes','no')
predict_df['predict_cosine_hypo'] = np.where(predict_df[3] == predict_df[13],'yes','no')
predict_df['predict_jaccard'] = np.where(predict_df[3] == predict_df[14],'yes','no')

# %%
predict_df['predict_cosine_hyper'].value_counts()
# Out:
# no     1087
# yes     370
# Name: predict_cosine_hyper, dtype: int64

# %%
predict_df['predict_cosine_hypo'].value_counts()
# Out:
# no     1114
# yes     343
# Name: predict_cosine_hypo, dtype: int64

# %%
predict_df['predict_jaccard'].value_counts()
# Out:
# no     1348
# yes     109
# Name: predict_jaccard, dtype: int64

# %%
from time import time
start_nb = time()

# %%
import logging
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s')

sentence_obama = 'Obama speaks to the media in Illinois'
sentence_president = 'The president greets the press in Chicago'
sentence_obama = sentence_obama.lower().split()
sentence_president = sentence_president.lower().split()

# %%
# Import and download stopwords from NLTK.
from nltk.corpus import stopwords
from nltk import download
download('stopwords')  # Download stopwords list.

# Remove stopwords.
stop_words = stopwords.words('english')
sentence_obama = [w for w in sentence_obama if w not in stop_words]
sentence_president = [w for w in sentence_president if w not in stop_words]
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jyotsnaprasad/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
start = time()
import os

import gensim
from gensim.models import Word2Vec
if not os.path.exists('GoogleNews-vectors-negative300.bin.gz'):
    raise ValueError("SKIP: You need to download the google news model")
    
model = gensim.models.KeyedVectors.load_word2vec_format('GoogleNews-vectors-negative300.bin.gz', binary=True)

# %%
print('Cell took %.2f seconds to run.' % (time() - start))
# Out:
# Cell took 36.65 seconds to run.

# %%
distance = model.wmdistance(sentence_obama, sentence_president)
print ('distance = %.4f' % distance)
# Out:
# distance = 3.3741

# %%
train_set5
# Out:
#           0                                                  1   \
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# 5        s_5  The tech-loaded Nasdaq composite rose 20.96 po...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                      2   \
# 1     But other sources close to the sale said Viven...
# 2     Micron's numbers also marked the first quarter...
# ...

# %%
def wmd(f):   
    sent1 = list(f[6])
    sent2 = list(f[7])
    
    sent1 = [w for w in sent1 if w not in stop_words]
    sent2 = [w for w in sent2 if w not in stop_words]

    distance = model.wmdistance(sent1, sent2)
    return distance

# %%
train_set5[18] = train_set5.apply(wmd,axis = 1)
# Out:
# /Users/jyotsnaprasad/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
train_set5
# Out:
#           0                                                  1   \
# 1        s_1  But other sources close to the sale said Viven...
# 2        s_2  Micron has declared its first quarterly profit...
# 3        s_3  The fines are part of failed Republican effort...
# 4        s_4  The American Anglican Council, which represent...
# 5        s_5  The tech-loaded Nasdaq composite rose 20.96 po...
# ...      ...                                                ...
# 1453  s_1480  Action is needed quickly, which is why we deci...
# 1454  s_1481  One could indeed wish for more and for improve...
# 1455  s_1482           (Parliament accepted the oral amendment)
# 1456  s_1483  - My party has serious reservations about Comm...
# 1457  s_1484                                 He saw a red rose.
#
#                                                      2   \
# 1     But other sources close to the sale said Viven...
# 2     Micron's numbers also marked the first quarter...
# ...

# %%
predict_df_wmd = train_set5[[18]].copy()

# %%
predict_df = predict_df.join(predict_df_wmd)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-202-5041525e7b34> in <module>
# ----> 1 predict_df = predict_df.join(predict_df_wmd)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    7244         # For SparseDataFrame's benefit
#    7245         return self._join_compat(
# -> 7246             other, on=on, how=how, lsuffix=lsuffix, rsuffix=rsuffix, sort=sort
#    7247         )
#    7248
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    7267                 right_index=True,
#    7268                 suffixes=(lsuffix, rsuffix),
# -> 7269                 sort=sort,
#    7270             )
#    7271         else:
#
# ...

# %%
predict_df_wmd = predict_df_wmd.apply(pd.to_numeric)

# %%
import numpy as np 
conditions = [
    (predict_df[18] == 0),
    (predict_df[18] >= 1) & (predict_df[18] < 2),
    (predict_df[18] >= 2) & (predict_df[18] < 3), 
    (predict_df[18] >= 3) & (predict_df[18] < 4), 
    (predict_df[18] >= 4)
    ]
choices = [5,4,3,2,1]

predict_df['predict_wmd'] = np.select(conditions, choices, default=0)

# %%
predict_df
# Out:
#         3  11  13  14 predict_cosine_hyper predict_cosine_hypo  \
# 1     4.0   4   2   2                  yes                  no
# 2     4.0   2   2   1                   no                  no
# 3     3.0   3   2   2                  yes                  no
# 4     3.0   4   4   2                   no                  no
# 5     2.0   3   3   1                   no                  no
# ...   ...  ..  ..  ..                  ...                 ...
# 1453  5.0   2   3   1                   no                  no
# 1454  5.0   2   1   1                   no                  no
# 1455  5.0   5   5   4                  yes                 yes
# 1456  5.0   4   3   2                   no                  no
# 1457  1.0   2   1   1                   no                 yes
#
#      predict_jaccard        18  predict_wmd
# 1                 no  1.204291            4
# 2                 no  1.635829            4
# 3                 no  1.453599            4
# ...

# %%
predict_df['accuracy_wmd'] = np.where(predict_df[3] == predict_df["predict_wmd"],'yes','no')

# %%
predict_df
# Out:
#         3  11  13  14 predict_cosine_hyper predict_cosine_hypo  \
# 1     4.0   4   2   2                  yes                  no
# 2     4.0   2   2   1                   no                  no
# 3     3.0   3   2   2                  yes                  no
# 4     3.0   4   4   2                   no                  no
# 5     2.0   3   3   1                   no                  no
# ...   ...  ..  ..  ..                  ...                 ...
# 1453  5.0   2   3   1                   no                  no
# 1454  5.0   2   1   1                   no                  no
# 1455  5.0   5   5   4                  yes                 yes
# 1456  5.0   4   3   2                   no                  no
# 1457  1.0   2   1   1                   no                 yes
#
#      predict_jaccard        18  predict_wmd accuracy_wmd
# 1                 no  1.204291            4          yes
# 2                 no  1.635829            4          yes
# ...

# %%
predict_df['accuracy_wmd'].value_counts()
# Out:
# no     968
# yes    489
# Name: accuracy_wmd, dtype: int64
